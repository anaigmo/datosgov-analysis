# %%
from SPARQLWrapper import SPARQLWrapper
from rdflib import Graph, RDF, DCAT
import requests
from pyshacl import validate

# %%
## primer intento, sale error de certificado:
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)>
def run_query(query):
    sparql.setReturnFormat('json')
    sparql.setQuery(query)
    try:
        results = sparql.queryAndConvert()
        return(results)
    except Exception as e:
        print(e)

sparql = SPARQLWrapper(
    'https://datos.gob.es/virtuoso/sparql'
)

# %%
url = 'https://datos.gob.es/virtuoso/sparql'
query = """
    PREFIX dct: <http://purl.org/dc/terms/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX dcat: <http://www.w3.org/ns/dcat#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    
    DESCRIBE ?dataset ?distribution ?format ?media_type
    WHERE
    {
        # ?dataset a dcat:Dataset ;
            dct:publisher ?publisher ;
            dcat:distribution ?distribution  .
        # ?publisher foaf:name ?publisher_name.
        OPTIONAL {?distribution dct:format ?format }
        OPTIONAL {?distribution dcat:mediaType ?media_type }
        
        FILTER (CONTAINS (lcase(?publisher_name), "ministerio de sanidad"))
    }
"""

headers = {
    "Accept": "text/turtle"
}

res = requests.get(url, params={"query": query}, verify=False, headers=headers)
#print(r.text)
# Out:
# /Users/ana/Git/datosgov-analysis/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'datos.gob.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
graph = Graph()
graph.parse(data=res.text, format="turtle")

print(f"Grafo cargado con {len(graph)} tripletas")

shapes = Graph()
shapes.parse('shapes.ttl', format='ttl')
print(f"{len(shapes)} shapes cargadas")

graph.serialize('output/datasets.ttl', format='ttl')
# Out:
# Grafo cargado con 408 tripletas
# 8 shapes cargadas
# <Graph identifier=N7549cb07b8e448c4863a1b1bb1719556 (<class 'rdflib.graph.Graph'>)>

# %%
shapes = Graph()
shapes.parse('shapes.ttl', format='ttl')

conforms, report_graph, report_text = validate(
    graph,
    shacl_graph=shapes,
    #inference='rdfs',   # opcional: "rdfs", "owlrl", "none"
    abort_on_first=False,
    meta_shacl=False,
    advanced=True,
    debug=False
)

print(report_text)
# Out:
# Validation Report
# Conforms: False
# Results (46):
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-acuerdos-adoptados-en-pleno-del-sistema-nacional-de-salud-sns
# 	Value Node: ns7:914ee207-6c81-48a5-848e-e8db6acd284a
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns7:914ee207-6c81-48a5-848e-e8db6acd284a
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns7:914ee207-6c81-48a5-848e-e8db6acd284a->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-acuerdos-adoptados-en-pleno-del-sistema-nacional-de-salud-sns
# 	Value Node: ns7:f096fa7b-3a6f-4597-a81f-b99c7dd96d23
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns7:f096fa7b-3a6f-4597-a81f-b99c7dd96d23
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns7:f096fa7b-3a6f-4597-a81f-b99c7dd96d23->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-acuerdos-adoptados-en-pleno-del-sistema-nacional-de-salud-sns
# 	Value Node: ns7:5387c3c7-feb8-4511-a15b-220e718286a1
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns7:5387c3c7-feb8-4511-a15b-220e718286a1
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns7:5387c3c7-feb8-4511-a15b-220e718286a1->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-catalogo-de-la-biblioteca-central-del-ministerio-de-sanidad-servicios-sociales-e-igualdad
# 	Value Node: ns14:eed148e8-52fb-4cc6-9686-823410986227
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns14:eed148e8-52fb-4cc6-9686-823410986227
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns14:eed148e8-52fb-4cc6-9686-823410986227->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-farmacia-nomenclator-de-facturacion
# 	Value Node: <https://datos.gob.es/catalogo/e05070101-farmacia-nomenclator-de-facturacion/resource/6d88e46d-350b-419d-8e53-d58c48b00e1f>
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: <https://datos.gob.es/catalogo/e05070101-farmacia-nomenclator-de-facturacion/resource/6d88e46d-350b-419d-8e53-d58c48b00e1f>
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-farmacia-nomenclator-de-facturacion/resource/6d88e46d-350b-419d-8e53-d58c48b00e1f>->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-catalogo-de-centros-de-atencion-primaria-del-sns
# 	Value Node: <https://datos.gob.es/catalogo/e05070101-catalogo-de-centros-de-atencion-primaria-del-sns/resource/4b0e9536-dcc4-4005-b718-49414dc4fccc>
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: <https://datos.gob.es/catalogo/e05070101-catalogo-de-centros-de-atencion-primaria-del-sns/resource/4b0e9536-dcc4-4005-b718-49414dc4fccc>
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-catalogo-de-centros-de-atencion-primaria-del-sns/resource/4b0e9536-dcc4-4005-b718-49414dc4fccc>->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-catalogo-de-centros-de-atencion-primaria-del-sns
# 	Value Node: <https://datos.gob.es/catalogo/e05070101-catalogo-de-centros-de-atencion-primaria-del-sns/resource/294edf89-a0d6-495e-be45-353385da6052>
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: <https://datos.gob.es/catalogo/e05070101-catalogo-de-centros-de-atencion-primaria-del-sns/resource/294edf89-a0d6-495e-be45-353385da6052>
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-catalogo-de-centros-de-atencion-primaria-del-sns/resource/294edf89-a0d6-495e-be45-353385da6052>->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-informativas
# 	Value Node: <https://datos.gob.es/catalogo/e05070101-informativas/resource/24ef1a2f-fd85-40fd-868d-e3aee4608e90>
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: <https://datos.gob.es/catalogo/e05070101-informativas/resource/24ef1a2f-fd85-40fd-868d-e3aee4608e90>
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-informativas/resource/24ef1a2f-fd85-40fd-868d-e3aee4608e90>->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-informacion-y-estadisticas-sanitarias-de-las-comunidades-autonomas
# 	Value Node: ns33:b6ff1940-da3d-4f49-8043-fc95db724e3a
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns33:b6ff1940-da3d-4f49-8043-fc95db724e3a
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns33:b6ff1940-da3d-4f49-8043-fc95db724e3a->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-informacion-y-estadisticas-sanitarias-de-las-comunidades-autonomas
# 	Value Node: ns33:570c8a23-1d49-4869-a9fd-ae99d63ebf5a
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns33:570c8a23-1d49-4869-a9fd-ae99d63ebf5a
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns33:570c8a23-1d49-4869-a9fd-ae99d63ebf5a->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-banco-de-datos-del-ministerio-de-sanidad-servicios-sociales-e-igualdad
# 	Value Node: ns9:dfa3dc97-745a-4612-9c8f-80e214e7462e
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns9:dfa3dc97-745a-4612-9c8f-80e214e7462e
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns9:dfa3dc97-745a-4612-9c8f-80e214e7462e->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-consejo-interterritorial-del-sistema-nacional-de-salud-ordenes-del-dia
# 	Value Node: ns20:e67566a0-67d4-4ce7-b084-77e1fac2829c
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns20:e67566a0-67d4-4ce7-b084-77e1fac2829c
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns20:e67566a0-67d4-4ce7-b084-77e1fac2829c->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales
# 	Value Node: <https://datos.gob.es/catalogo/e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales/resource/3fd59a76-276d-44a4-8ef2-deabbfc64be0>
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: <https://datos.gob.es/catalogo/e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales/resource/3fd59a76-276d-44a4-8ef2-deabbfc64be0>
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales/resource/3fd59a76-276d-44a4-8ef2-deabbfc64be0>->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales
# 	Value Node: <https://datos.gob.es/catalogo/e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales/resource/4e37b416-a570-4138-adef-c3a56dd5421a>
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: <https://datos.gob.es/catalogo/e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales/resource/4e37b416-a570-4138-adef-c3a56dd5421a>
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales/resource/4e37b416-a570-4138-adef-c3a56dd5421a>->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-catalogo-de-publicaciones-del-ministerio-de-sanidad-consumo-bienestar-social
# 	Value Node: ns16:ac2349c5-f42d-40b1-a29f-a5790864ad3f
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns16:ac2349c5-f42d-40b1-a29f-a5790864ad3f
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns16:ac2349c5-f42d-40b1-a29f-a5790864ad3f->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-evolucion-de-enfermedad-por-el-coronavirus-covid-19
# 	Value Node: ns28:0a1008c4-d88b-4cb4-82b4-f0fae96ed44b
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns28:0a1008c4-d88b-4cb4-82b4-f0fae96ed44b
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns28:0a1008c4-d88b-4cb4-82b4-f0fae96ed44b->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-evolucion-de-enfermedad-por-el-coronavirus-covid-19
# 	Value Node: ns28:e4c99afe-3ab4-472d-b772-5e85c8924c7a
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns28:e4c99afe-3ab4-472d-b772-5e85c8924c7a
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns28:e4c99afe-3ab4-472d-b772-5e85c8924c7a->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-evolucion-de-enfermedad-por-el-coronavirus-covid-19
# 	Value Node: ns28:130e7f28-4acf-4260-aa25-ca94a66d97aa
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns28:130e7f28-4acf-4260-aa25-ca94a66d97aa
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns28:130e7f28-4acf-4260-aa25-ca94a66d97aa->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-evolucion-de-enfermedad-por-el-coronavirus-covid-19
# 	Value Node: ns28:3268aad0-5c84-4b47-8bb1-65be44971455
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns28:3268aad0-5c84-4b47-8bb1-65be44971455
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns28:3268aad0-5c84-4b47-8bb1-65be44971455->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-evolucion-de-enfermedad-por-el-coronavirus-covid-19
# 	Value Node: ns28:daac0e06-2e78-49a6-a2b4-dfbdc0402ca1
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns28:daac0e06-2e78-49a6-a2b4-dfbdc0402ca1
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns28:daac0e06-2e78-49a6-a2b4-dfbdc0402ca1->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-evolucion-de-enfermedad-por-el-coronavirus-covid-19
# 	Value Node: ns28:5893e476-84dc-4723-be00-ff455a4ebfed
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns28:5893e476-84dc-4723-be00-ff455a4ebfed
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns28:5893e476-84dc-4723-be00-ff455a4ebfed->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-de-vacunacion-covid-19-en-espana
# 	Value Node: ns22:fc86ba02-05ce-4dc3-9f25-ccdd3a306747
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: ns22:fc86ba02-05ce-4dc3-9f25-ccdd3a306747
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on ns22:fc86ba02-05ce-4dc3-9f25-ccdd3a306747->dcat:mediaType
# Constraint Violation in NodeConstraintComponent (http://www.w3.org/ns/shacl#NodeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:node :DistributionShape ; sh:path dcat:distribution ]
# 	Focus Node: ns2:e05070101-informe-anual-del-sistema-nacional-de-salud
# 	Value Node: <https://datos.gob.es/catalogo/e05070101-informe-anual-del-sistema-nacional-de-salud/resource/4876c0f8-ae98-4b82-a59b-2f4dcd76b2c7>
# 	Result Path: dcat:distribution
# 	Message: Value does not conform to Shape :DistributionShape. See details for more information.
# 	Details:
# 		Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 			Severity: sh:Violation
# 			Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 			Focus Node: <https://datos.gob.es/catalogo/e05070101-informe-anual-del-sistema-nacional-de-salud/resource/4876c0f8-ae98-4b82-a59b-2f4dcd76b2c7>
# 			Result Path: dcat:mediaType
# 			Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-informe-anual-del-sistema-nacional-de-salud/resource/4876c0f8-ae98-4b82-a59b-2f4dcd76b2c7>->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns9:dfa3dc97-745a-4612-9c8f-80e214e7462e
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns9:dfa3dc97-745a-4612-9c8f-80e214e7462e->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns28:0a1008c4-d88b-4cb4-82b4-f0fae96ed44b
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns28:0a1008c4-d88b-4cb4-82b4-f0fae96ed44b->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: <https://datos.gob.es/catalogo/e05070101-informe-anual-del-sistema-nacional-de-salud/resource/4876c0f8-ae98-4b82-a59b-2f4dcd76b2c7>
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-informe-anual-del-sistema-nacional-de-salud/resource/4876c0f8-ae98-4b82-a59b-2f4dcd76b2c7>->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns28:130e7f28-4acf-4260-aa25-ca94a66d97aa
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns28:130e7f28-4acf-4260-aa25-ca94a66d97aa->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns22:fc86ba02-05ce-4dc3-9f25-ccdd3a306747
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns22:fc86ba02-05ce-4dc3-9f25-ccdd3a306747->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: <https://datos.gob.es/catalogo/e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales/resource/4e37b416-a570-4138-adef-c3a56dd5421a>
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales/resource/4e37b416-a570-4138-adef-c3a56dd5421a>->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns16:ac2349c5-f42d-40b1-a29f-a5790864ad3f
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns16:ac2349c5-f42d-40b1-a29f-a5790864ad3f->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns28:daac0e06-2e78-49a6-a2b4-dfbdc0402ca1
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns28:daac0e06-2e78-49a6-a2b4-dfbdc0402ca1->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns33:b6ff1940-da3d-4f49-8043-fc95db724e3a
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns33:b6ff1940-da3d-4f49-8043-fc95db724e3a->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns33:570c8a23-1d49-4869-a9fd-ae99d63ebf5a
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns33:570c8a23-1d49-4869-a9fd-ae99d63ebf5a->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns28:5893e476-84dc-4723-be00-ff455a4ebfed
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns28:5893e476-84dc-4723-be00-ff455a4ebfed->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns7:914ee207-6c81-48a5-848e-e8db6acd284a
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns7:914ee207-6c81-48a5-848e-e8db6acd284a->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns7:5387c3c7-feb8-4511-a15b-220e718286a1
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns7:5387c3c7-feb8-4511-a15b-220e718286a1->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: <https://datos.gob.es/catalogo/e05070101-farmacia-nomenclator-de-facturacion/resource/6d88e46d-350b-419d-8e53-d58c48b00e1f>
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-farmacia-nomenclator-de-facturacion/resource/6d88e46d-350b-419d-8e53-d58c48b00e1f>->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: <https://datos.gob.es/catalogo/e05070101-catalogo-de-centros-de-atencion-primaria-del-sns/resource/294edf89-a0d6-495e-be45-353385da6052>
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-catalogo-de-centros-de-atencion-primaria-del-sns/resource/294edf89-a0d6-495e-be45-353385da6052>->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns14:eed148e8-52fb-4cc6-9686-823410986227
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns14:eed148e8-52fb-4cc6-9686-823410986227->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns20:e67566a0-67d4-4ce7-b084-77e1fac2829c
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns20:e67566a0-67d4-4ce7-b084-77e1fac2829c->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns28:e4c99afe-3ab4-472d-b772-5e85c8924c7a
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns28:e4c99afe-3ab4-472d-b772-5e85c8924c7a->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns28:3268aad0-5c84-4b47-8bb1-65be44971455
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns28:3268aad0-5c84-4b47-8bb1-65be44971455->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: <https://datos.gob.es/catalogo/e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales/resource/3fd59a76-276d-44a4-8ef2-deabbfc64be0>
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-centros-y-servicios-del-sns-catalogo-nacional-de-hospitales/resource/3fd59a76-276d-44a4-8ef2-deabbfc64be0>->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: <https://datos.gob.es/catalogo/e05070101-catalogo-de-centros-de-atencion-primaria-del-sns/resource/4b0e9536-dcc4-4005-b718-49414dc4fccc>
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-catalogo-de-centros-de-atencion-primaria-del-sns/resource/4b0e9536-dcc4-4005-b718-49414dc4fccc>->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: ns7:f096fa7b-3a6f-4597-a81f-b99c7dd96d23
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on ns7:f096fa7b-3a6f-4597-a81f-b99c7dd96d23->dcat:mediaType
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: [ sh:minCount Literal("1", datatype=xsd:integer) ; sh:path dcat:mediaType ]
# 	Focus Node: <https://datos.gob.es/catalogo/e05070101-informativas/resource/24ef1a2f-fd85-40fd-868d-e3aee4608e90>
# 	Result Path: dcat:mediaType
# 	Message: Less than 1 values on <https://datos.gob.es/catalogo/e05070101-informativas/resource/24ef1a2f-fd85-40fd-868d-e3aee4608e90>->dcat:mediaType

# %%
def url_accessibility(graph, predicate, violation_nodes):
    res = {}
    for dist in graph.subjects(RDF.type, DCAT.Distribution):
        if dist not in violation_nodes:
            for url in graph.objects(dist, predicate):
                try:
                    r = requests.head(str(url), allow_redirects=True, timeout=5)
                    if r.status_code == 200:
                        res[str(url)] = 'OK'
                    else: 
                        res[str(url)] = f'Error {r.status_code}'
                except Exception as e:
                    res[str(url)] = f'Failed: {e}'
    return res

query = """
    PREFIX sh: <http://www.w3.org/ns/shacl#>
    SELECT DISTINCT ?node 
    WHERE {
        # ?s sh:focusNode ?node ;
        sh:resultPath ?property
        VALUES ?property { dcat:accessURL dcat:downloadURL }
    }
"""

res = list(report_graph.query(query))
violation_nodes = [str(row['node']) for row in res]

accessURL_acc = url_accessibility(graph, DCAT.accessURL, violation_nodes)
downloadURL_acc = url_accessibility(graph, DCAT.downloadURL, violation_nodes)

# %%
accessURL_acc
#downloadURL_acc
# Out:
# {'http://www.mscbs.gob.es/organizacion/consejoInterterritorial.do': 'OK',
#  'http://www.adobe.com/prodindex/acrobat/readstep.html': 'OK',
#  'http://www.mscbs.gob.es/estadEstudios/estadisticas/bancoDatos.htm': 'OK',
#  'https://www.sanidad.gob.es/estadEstudios/estadisticas/sisInfSanSNS/ofertaRecursos/centrosSalud/home.htm': 'OK',
#  'https://www.sanidad.gob.es/ciudadanos/centros.do': 'OK',
#  'http://www.mscbs.gob.es/biblioPublic/biblioDocum/biblioCentral/libros.htm': 'OK',
#  'http://www.mscbs.gob.es/biblioPublic/publicaciones.do': 'OK',
#  'http://www.mscbs.gob.es/ciudadanos/centros.do': 'OK',
#  'http://www.mscbs.gob.es/ciudadanos/prestaciones/centrosServiciosSNS/hospitales/home.htm': 'OK',
#  'http://www.mscbs.gob.es/organizacion/consejoInterterri/ordenes.htm': 'OK',
#  'https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov/vacunaCovid19.htm': 'Error 404',
#  'https://cnecovid.isciii.es/covid19/': 'OK',
#  'https://portalcne.isciii.es/enecovid19/': 'OK',
#  'https://cnecovid.isciii.es/covid19/resources/casos_diagnostico_ccaa.csv': 'OK',
#  'https://www.isciii.es/QueHacemos/Servicios/VigilanciaSaludPublicaRENAVE/EnfermedadesTransmisibles/Paginas/InformesCOVID-19.aspx': 'OK',
#  'https://cnecovid.isciii.es/covid19/resources/casos_diagnostico_provincia.csv': 'OK',
#  'https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm': 'Error 404',
#  'http://www.mscbs.gob.es/profesionales/nomenclator.do?metodo=buscarProductos&especialidad=%25%25%25&d-4015021-e=1&6578706f7274=1': 'OK',
#  'http://www.mscbs.gob.es/estadEstudios/estadisticas/estadisticas/REBECA_Areas_tematicas.htm': 'OK',
#  'http://www.mscbs.gob.es/estadEstudios/estadisticas/estadisticas/infEstadisticasCCAA.htm': 'OK',
#  'http://www.mscbs.gob.es/campannas/portada/campanasInformativas.csv': 'OK',
#  'http://www.mscbs.gob.es/estadEstudios/estadisticas/sisInfSanSNS/tablasEstadisticas/informeAnualSNS.csv': 'OK'}
